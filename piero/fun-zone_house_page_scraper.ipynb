# %%
#################################################################################33
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import json
import pandas  as pd

# %%
def get_property(url):
    driver = webdriver.Chrome()
    driver.get(url)

    #Pass the cookkie banner
    time.sleep(2) #its better in a loop
    banner_button = driver.find_element(By.XPATH,'//*[@id="uc-btn-accept-banner"]').click()

    #info = driver.find_element(By.CLASS_NAME,'classified')  #Gets all info in the page
    #info = driver.find_element(By.XPATH,'//head/script[contains(text(),"window.dataLayer")]')
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    element_info = soup.select('div.classified script')

    #print(type(element_info))
    text = element_info[0].text

    driver.close()

    #print(text[33:-2])

    return json.loads("".join(("".join(text.split('=')[1:]).split(";")[:-1])))
get_property('https://www.immoweb.be/en/classified/house/for-sale/ixelles/1050/10008022?searchId=6336981899ac0')
# Out:
# {'id': 10008022,
#  'cluster': None,
#  'customers': [{'id': 2938005,
#    'type': 'AGENCY',
#    'email': 'jamesrea_ixelles@importfrommedia.be',
#    'logoUrl': 'https://static.immoweb.be/logos/2938005.gif?cache2021511006150',
#    'phoneNumber': '+32 2 218 38 38',
#    'mobileNumber': None,
#    'name': 'James Realty',
#    'website': 'http://www.james-realty.com',
#    'location': {'country': 'Belgium',
#     'region': None,
#     'province': 'Brussels',
#     'district': 'Brussels',
#     'locality': 'Ixelles',
#     'postalCode': '1050',
#     'street': 'Avenue Legrand 30',
#     'number': None,
#     'box': None,
#     'propertyName': None,
#     'floor': None,
#     'latitude': 50.82,
#     'longitude': 4.37,
#     'distance': None,
#     'approximated': None,
#     'regionCode': None,
#     'type': None,
#     'hasSeaView': None,
#     'pointsOfInterest': None,
#     'placeName': None},
#    'ipiNo': '105.256',
#    'isOwner': True,
#    'contactHoursMobile': 'anytime',
#    'contactHoursLandline': 'anytime',
#    'salesRepresentative': None,
#    'features': {'page404': True,
#     'investorFlag': False,
#     'relatedClassifieds': True,
#     'leafletsCTA': False,
#     'leadQualification': True,
#     'recommendation': True}}],
#  'premiumProjectPage': {'medias': None,
#   'options': None,
#   'promoter': None,
#   'tabs': None},
#  'flags': {'isPublicSale': False,
#   'isNewClassified': False,
#   'isNewPrice': False,
#   'isInvestmentProject': False,
#   'isNewlyBuilt': False,
#   'isNotarySale': None,
#   'isLifeAnnuitySale': False,
#   'adQuality': None,
#   'date': None,
#   'priceSqm': None,
#   'price': None,
#   'default': None,
#   'isSoldOrRented': False,
#   'isLowEnergy': None,
#   'percentSold': None,
#   'isPassiveHouse': None,
#   'isNewRealEstateProject': False,
#   'isAnInteractiveSale': None,
#   'isUnderOption': False},
#  'media': {'pictures': [{'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_1.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_1.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_1.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_2.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_2.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_2.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_3.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_3.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_3.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_4.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_4.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_4.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_5.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_5.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_5.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_6.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_6.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_6.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_7.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_7.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_7.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_8.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_8.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_8.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_9.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_9.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_9.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_0.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_0.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_0.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_A.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_A.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_A.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_B.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_B.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_B.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_C.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_C.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_C.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_D.gif?cache20220708050921',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_D.jpg?cache20220708050921',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_D.jpg?cache20220708050921',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_E.gif?cache20220708050922',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_E.jpg?cache20220708050922',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_E.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_F.gif?cache20220708050922',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_F.jpg?cache20220708050922',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_F.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_G.gif?cache20220708050922',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_G.jpg?cache20220708050922',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_G.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_H.gif?cache20220708050922',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_H.jpg?cache20220708050922',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_H.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_I.gif?cache20220708050922',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_I.jpg?cache20220708050922',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_I.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_J.gif?cache20220708050922',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_J.jpg?cache20220708050922',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_J.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_K.gif?cache20220708050922',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_K.jpg?cache20220708050922',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_K.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_L.gif?cache20220708050922',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_L.jpg?cache20220708050922',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_L.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_M.gif?cache20220708050923',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_M.jpg?cache20220708050923',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_M.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_N.gif?cache20220708050923',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_N.jpg?cache20220708050923',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_N.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_O.gif?cache20220708050923',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_O.jpg?cache20220708050923',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_O.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_P.gif?cache20220708050923',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_P.jpg?cache20220708050923',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_P.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_Q.gif?cache20220708050923',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_Q.jpg?cache20220708050923',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_Q.jpg?cache20220708050922',
#     'isVertical': False},
#    {'smallUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_R.gif?cache20220708050923',
#     'mediumUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/M_10008022_R.jpg?cache20220708050923',
#     'largeUrl': 'https://static.immoweb.be/photos/1/0/0/0/8/0/2/2/10008022_R.jpg?cache20220708050923',
#     'isVertical': False}],
#   'virtualTourUrl': None,
#   'floorPlans': None,
#   'specifications': None,
#   'virtualExperienceUrl': None},
#  'property': {'type': 'HOUSE',
#   'subtype': 'HOUSE',
#   'title': None,
#   'description': "Atypical house with character: very well located just a stone's throw from Rue Edith Cavell and close to all the shops on Rue Vanderkindere, we offer you this Beaux-Arts style mansion which underwent a thorough renovation a few years ago. It offers, past the entrance hall, a nice office on the ground floor and, on the upper floors, the following living program: large reception rooms with character, a hyper-equipped Obumex kitchen opening onto the terrace and the garden (perfectly facing west), a separate dining room and, on the 2nd and 3rd floors, the master suite with its complete bathroom and its dressing room, a nice office-library and two other bedrooms with their own shower room as well as a small office or dressing room. At the bottomof the garden there is a lovely back house with a large space on the ground floor and, on the first floor, a beautiful bedroom and a shower room. Pretty town garden currently paved. A garage box in the immediate vicinity (rue Marie Depage 75) completes this beautiful property and possibility of acquiring two additional (50,000€/box).  The property: Mansion of +/-416m2 living space and 558m2 built area with basements Very good condition Light and character  Large reception rooms 3 bedrooms and 2 shower rooms Office and library The back house of +/-100m2 useful Large multi-purpose space 1 bedroom and 1 shower Kitchenette  The area: 2 steps from Edith Cavell street Elegant and quiet street Numerous food shops nearby  Information given for inf",
#   'name': None,
#   'isHolidayProperty': None,
#   'bedroomCount': 4,
#   'bedrooms': [],
#   'bathroomCount': 3,
#   'bathrooms': [],
#   'location': {'country': 'Belgium',
#    'region': 'Brussels',
#    'province': 'Brussels',
#    'district': 'Brussels',
#    'locality': 'Ixelles',
#    'postalCode': '1050',
#    'street': None,
#    'number': None,
#    'box': None,
#    'propertyName': None,
#    'floor': None,
#    'latitude': None,
#    'longitude': None,
#    'distance': None,
#    'approximated': None,
#    'regionCode': 'BRUSSELS',
#    'type': None,
#    'hasSeaView': None,
#    'pointsOfInterest': None,
#    'placeName': None},
#   'netHabitableSurface': None,
#   'roomCount': 5,
#   'monthlyCosts': None,
#   'attic': None,
#   'hasAttic': None,
#   'basement': {'surface': None},
#   'hasBasement': True,
#   'hasDressingRoom': None,
#   'diningRoom': None,
#   'hasDiningRoom': None,
#   'building': {'annexCount': None,
#    'condition': 'AS_NEW',
#    'constructionYear': 1930,
#    'facadeCount': 2,
#    'floorCount': None,
#    'streetFacadeWidth': 6.5},
#   'propertyCertificates': None,
#   'hasCaretakerOrConcierge': None,
#   'hasDisabledAccess': False,
#   'hasLift': False,
#   'constructionPermit': {'constructionType': None,
#    'floodZoneType': None,
#    'isObtained': True,
#    'hasObligationToConstruct': None,
#    'hasPlotDivisionAuthorization': None,
#    'hasPossiblePriorityPurchaseRight': None,
#    'isBreachingUrbanPlanningRegulation': None,
#    'floodZoneIconUrl': None,
#    'totalBuildableGroundFloorSurface': 658,
#    'urbanPlanningInformation': None},
#   'energy': {'heatingType': 'GAS',
#    'hasHeatPump': None,
#    'hasPhotovoltaicPanels': None,
#    'hasThermicPanels': None,
#    'hasCollectiveWaterHeater': None,
#    'hasDoubleGlazing': None,
#    'performance': None},
#   'kitchen': {'surface': None,
#    'type': 'USA_HYPER_EQUIPPED',
#    'hasOven': None,
#    'hasMicroWaveOven': None,
#    'hasDishwasher': None,
#    'hasWashingMachine': None,
#    'hasFridge': None,
#    'hasFreezer': None,
#    'hasSteamOven': None},
#   'land': {'hasGasWaterElectricityConnection': None,
#    'hasPlotToRear': None,
#    'isFacingStreet': None,
#    'isFlat': None,
#    'isWooded': None,
#    'landWidth': 0,
#    'latestUseDesignation': None,
#    'rearLand': None,
#    'sewerConnection': None,
#    'surface': 290},
#   'laundryRoom': None,
#   'hasLaundryRoom': None,
#   'livingRoom': None,
#   'hasLivingRoom': True,
#   'isFirstOccupation': None,
#   'hasBalcony': None,
#   'hasBarbecue': None,
#   'hasGarden': True,
#   'gardenSurface': 140,
#   'gardenOrientation': None,
#   'parkingCountIndoor': 1,
#   'parkingCountOutdoor': None,
#   'parkingCountClosedBox': None,
#   'hasAirConditioning': None,
#   'hasArmoredDoor': None,
#   'hasVisiophone': None,
#   'hasSecureAccessAlarm': None,
#   'hasCableTV': None,
#   'hasDoorPhone': True,
#   'hasInternet': None,
#   'showerRoomCount': 0,
#   'showerRooms': [],
#   'specificities': {'internalFixturesAndFittings': None,
#    'miscellaneousFixturesAndFittings': None,
#    'totalFloorSurface': None,
#    'accessDoorCount': None,
#    'sectionalDoorCount': None,
#    'slidingDoorCount': None,
#    'loadingBayCount': None,
#    'coveredBaysCount': None,
#    'loadingBayWithLiftingDeviceCount': None,
#    'ceilingHeight': None,
#    'maxAvailableHeight': None,
#    'minAvailableHeight': None,
#    'showroomSurface': None,
#    'hasReceptionDesk': None,
#    'shopWindowWidth': None,
#    'hasGoodwill': None,
#    'goodwillPrice': None,
#    'hasOffice': True,
#    'office': None,
#    'hasWorkspace': None,
#    'workspace': None},
#   'toiletCount': 4,
#   'toilets': [],
#   'hasFitnessRoom': None,
#   'hasTennisCourt': None,
#   'hasSwimmingPool': False,
#   'hasSauna': None,
#   'hasJacuzzi': None,
#   'hasHammam': None,
#   'bedroomSurface': None,
#   'alternativeDescriptions': {'fr': "Maison atypique et de caractère: très bien située à deux pas de la rue Edith Cavell et proche de tous les commerces de bouche de la rue Vanderkindere, nous vous proposons cet hôtel de maître de style Beaux-Arts qui a fait l'objet d'une rénovation profonde il y a quelques années. Elle offre, passée l'entrée cochère, un joli bureau au rez-de-chaussée et, aux étages, le programme de vie suivant: grandes réceptions de caractère, cuisine hyper-équipée Obumex s'ouvrant sur la terrasse et le jardin (parfaitement orienté ouest), une salle à manger séparée et, aux 2ème et 3ème, la suite parentale avec sa salle de bains complète et sa partie dressing, un beau bureau-bibliothèque et deux autres chambres avec leur salle d'eau ainsi qu'un petit bureau ou dressing. On retrouve au fond du jardin une ravissante arrière-maison avec un grand espace au rez-de-chaussée et, à l'étage, un belle chambre et un coin douche. Joli jardin de ville actuellement pavé. Un garage box à proximité immédiate (rue Marie Depage 75) complète ce beau bien et possibilité d'en acquérir deux supplémentaires (50.000€/box).  Le bien: Hôtel de maître de +/-416m2 habitables et 558m2 construits avec les sous-sols Très bel état Lumière et caractère  Grandes réceptions 3 chambres et 2 salles d'eau Bureau et bibliothèque L'arrière-maison de +/-100m2 utiles Grand espace polyvalent 1 chambre et 1 douche Kitchenette  Le quartier : A 2 pas de la rue Edith Cavell Rue élégante et calme Nombreux commerces de bouche à proximité  Inf",
#    'nl': 'Atypisch huis met karakter: zeer goed gelegen op een steenworp afstand van de Rue Edith Cavell en dicht bij alle winkels van de Rue Vanderkindere, bieden wij u dit herenhuis in Beaux-Arts stijl dat een paar jaar geleden een grondige renovatie onderging. Het biedt, voorbij de entreehal, een mooi kantoor op de begane grond en, op de verdiepingen, het volgende woonprogramma: grote ontvangstruimten met karakter, een hyper-uitgeruste Obumex keuken die uitkomt op het terras en de tuin (perfect op het westen gelegen), een aparte eetkamer en, op de 2e en 3e verdieping, de master suite met zijn complete badkamer en kleedkamer, een mooi kantoor-bibliotheek en twee andere slaapkamers met hun eigen doucheruimte, evenals een klein kantoor of kleedkamer.Onderaan de tuin is er een mooi achterhuis met een grote ruimte op de begane grond en, boven, een mooie slaapkamer en een doucheruimte. Mooie stadstuin momenteel verhard. Een garagebox in de onmiddellijke nabijheid (rue Marie Depage 75) vervolledigt dit mooie eigendom en mogelijkheid om er twee bij te kopen (50.000€/box).  Het eigendom: Herenhuis van +/-416m2 woonoppervlak en 558m2 bebouwd oppervlak met kelders Zeer goede staat Licht en karakter  Grote ontvangstruimten 3 slaapkamers en 2 doucheruimtes Kantoor en bibliotheek Het achterhuis van +/-100m2 nuttig Grote multifunctionele ruimte 1 slaapkamer en 1 douche Keukentje  Het gebied: 2 stappen van Edith Cavell straat Elegante en rustige straat Talrijke levensmiddelenwinkels in de buurt  D'},
#   'habitableUnitCount': None,
#   'fireplaceCount': None,
#   'fireplaceExists': False,
#   'hasTerrace': True,
#   'terraceSurface': None,
#   'terraceOrientation': None},
#  'publication': {'creationDate': '2022-07-08T05:08:14.000+0000',
#   'expirationDate': '2022-09-30T21:59:59.000+0000',
#   'publisherId': None,
#   'visualisationOption': 'XL',
#   'lastModificationDate': '2022-09-29T22:16:07.427+0000'},
#  'transaction': {'type': 'FOR_SALE',
#   'subtype': 'BUY_REGULAR',
#   'availabilityPeriodType': 'TO_BE_DEFINED',
#   'availabilityDate': None,
#   'certificates': {'carbonEmission': 113,
#    'hasElectricalInstallationComplianceCertificate': None,
#    'primaryEnergyConsumptionPerSqm': 565,
#    'primaryEnergyConsumptionYearly': None,
#    'epcDescription': None,
#    'epcReference': '202203170000608116018',
#    'epcScore': 'G',
#    'epcUrl': 'https://static.immoweb.be/en/pics/bxlG.gif'},
#   'rental': None,
#   'sale': {'price': 1790000,
#    'isSubjectToVat': False,
#    'cadastralIncome': 0,
#    'publicSale': None,
#    'pricePerSqm': None,
#    'oldPrice': None,
#    'lifeAnnuity': None,
#    'hasStartingPrice': False,
#    'isFurnished': False,
#    'homeToBuild': None},
#   'investor': {'isInvestmentProperty': False,
#    'currentMonthlyRentalIncome': None,
#    'currentReturnOnInvestment': None,
#    'expectedMonthlyRentalIncome': None,
#    'expectedMonthlyRentalIncomeDescription': None,
#    'expectedReturnOnInvestment': None,
#    'habitableUnitCount': None,
#    'occupancyRate': None}},
#  'priceType': None,
#  'price': {'type': 'residential_sale',
#   'mainValue': 1790000,
#   'alternativeValue': None,
#   'additionalValue': None,
#   'oldValue': None,
#   'minRangeValue': None,
#   'maxRangeValue': None,
#   'mainDisplayPrice': '€1,790,000',
#   'HTMLDisplayPrice': '<span aria-hidden"true">€1,790,000</span>',
#   'alternativeDisplayPrice': '',
#   'oldDisplayPrice': None,
#   'shortDisplayPrice': '€1.8M',
#   'accessibilityPrice': '1790000€',
#   'label': 'Price',
#   'date': None,
#   'language': 'en'},
#  'externalReference': '4836494',
#  'isBookmarked': False,
#  'hasSectionsArray': {'hasGeneralSection': True,
#   'hasInteriorSection': True,
#   'hasExteriorSection': True,
#   'hasFacilitiesSection': True,
#   'hasEnergySection': True,
#   'hasPlanningSection': True,
#   'hasFinancialSection': True,
#   'hasPublicSaleSection': False},
#  'unitGroupings': [],
#  'displayFlags': {'main': None, 'secondary': [], 'percentSold': None},
#  'statistics': {'bookmarkCount': 115,
#   'viewCount': 15845,
#   'alertPrice': None,
#   'creationDate': None,
#   'description': None,
#   'isAlertEmailSet': None,
#   'rating': None,
#   'wasOwnerContacted': None,
#   'wasPropertyVisited': None}}

# %%
list_list = [['https://www.immoweb.be/en/classified/house/for-sale/ixelles/1050/10008022?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/10125449'],[
'https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/10141214?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-st-lambert/1200/10052020?searchId=6336981899ac0'], 
['https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/gent/9000/10140797?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/roeselare/8800/10140738?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/house/for-sale/remicourt/4350/10140833?searchId=6336981899ac0'],[
'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-saint-lambert/1200/10140583?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/apartment/for-sale/deinze/9800/10130388?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/apartment/for-sale/kessel-lo/3010/10142174?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/opwijk/1745/10140459?searchId=6336981899ac0'],[ 
'https://www.immoweb.be/en/classified/house/for-sale/ronse/9600/10140837?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/brussels-city/1000/9881253?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/duplex/for-sale/wichelen/9260/10138456?searchId=6336981899ac0'],[
'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/zedelgem/8210/10074861?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/wondelgem/9032/10139511?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/apartment/for-sale/leuven/3010/10138534?searchId=6336981899ac0'],[
'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/schilde/2970/10139639?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/house/for-sale/ronse/9600/10138497?searchId=6336981899ac0'],[
'https://www.immoweb.be/en/classified/apartment/for-sale/wezembeek-oppem/1970/10140213?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/wetteren/9230/10138446?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/bruxelles/1000/10092917?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/uccle/1180/10138601?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-saint-lambert/1200/10138633?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/mixed-use-building/for-sale/grimbergen/1850/10138527?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/penthouse/for-sale/schaerbeek/1030/10142207?searchId=6336981899ac0'],[
'https://www.immoweb.be/en/classified/apartment-block/for-sale/ixelles/1050/10138311?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/flat-studio/for-sale/huy/4500/10137075?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/brasschaat/2930/10137774?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/flat-studio/for-sale/schaerbeek/1030/10137594?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/anderlecht/1070/10137324?searchId=6336981899ac0']]

for list in list_list:
    print(list)
# Out:
# ['https://www.immoweb.be/en/classified/house/for-sale/ixelles/1050/10008022?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/10125449']
# ['https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/10141214?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-st-lambert/1200/10052020?searchId=6336981899ac0']
# ['https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/gent/9000/10140797?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/roeselare/8800/10140738?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/house/for-sale/remicourt/4350/10140833?searchId=6336981899ac0']
# ['https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-saint-lambert/1200/10140583?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/apartment/for-sale/deinze/9800/10130388?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/apartment/for-sale/kessel-lo/3010/10142174?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/opwijk/1745/10140459?searchId=6336981899ac0']
# ['https://www.immoweb.be/en/classified/house/for-sale/ronse/9600/10140837?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/brussels-city/1000/9881253?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/duplex/for-sale/wichelen/9260/10138456?searchId=6336981899ac0']
# ['https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/zedelgem/8210/10074861?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/wondelgem/9032/10139511?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/apartment/for-sale/leuven/3010/10138534?searchId=6336981899ac0']
# ['https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/schilde/2970/10139639?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/house/for-sale/ronse/9600/10138497?searchId=6336981899ac0']
# ['https://www.immoweb.be/en/classified/apartment/for-sale/wezembeek-oppem/1970/10140213?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/wetteren/9230/10138446?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/bruxelles/1000/10092917?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/uccle/1180/10138601?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-saint-lambert/1200/10138633?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/mixed-use-building/for-sale/grimbergen/1850/10138527?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/penthouse/for-sale/schaerbeek/1030/10142207?searchId=6336981899ac0']
# ['https://www.immoweb.be/en/classified/apartment-block/for-sale/ixelles/1050/10138311?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/flat-studio/for-sale/huy/4500/10137075?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/brasschaat/2930/10137774?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/flat-studio/for-sale/schaerbeek/1030/10137594?searchId=6336981899ac0', 'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/anderlecht/1070/10137324?searchId=6336981899ac0']

# %%
url_list = list_list[1]
def url_to_list_dict(url_list):

   
    main_dictionary = dict()    

    
    for url in url_list:
        x = get_property(url)
        main_dictionary[url]=x
        json_object = json.dumps(x)
        list_dict=[]
        with open("Data.json","w") as data_file:
            data_file.write(json_object)
    #return json from url list
        for element in main_dictionary.keys():
            #print(main_dictionary.values())
            element_data = {
            'url': element,
            'id': x['id'],
            #'Locality': x['property']['location']['locality'],
            #'Type of property': x['property']['type'],
            #'Subtype of property': x['property']['subtype'],
            #'Price': x['price']['mainValue'],
            #'Type of sale': x['price']['type'],
            #'Number of rooms': '?',  #Dont know what to take
            #'Area': x['property']['netHabitableSurface'],
            ##'Fully equipped kitchen': x['property']['kitchen']['type'], #here are several values... look for fully equiped
            #'Furnished': '?',  #Dont know what to take
            #'Open fire': ['fireplaceExists'],
            #'Terrace': ['hasTerrace'],
            #'Terrace area': ['terraceSurface'],
            #'Garden': x['property']['hasGarden'],
            #'Garden area': x['property']['gardenSurface'],
            #'Surface of the land': x['property']['land']['surface'],
            #'Surface area of the plot of land': '?',  #Dont know what to take
            #'Number of facades ': x['property']['building']['facadeCount'],
            #'Swimming pool': x['property']['hasSwimmingPool'],
            #'State of the building': x['property']['building']['condition']    
            }
            #returns a dict from a json
            list_dict.append(element_data)
    return list_dict
main_data_file(url_list)
# Out:
# [{'url': 'https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/10141214?searchId=6336981899ac0',
#   'id': 10052020},
#  {'url': 'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-st-lambert/1200/10052020?searchId=6336981899ac0',
#   'id': 10052020}]

# %%
#def element_data(main_dictionary):
#    for element in main_dictionary.keys():
#        #print(main_dictionary.values())
#        element_data = {
#        'url': element,
#        'id': x['id'],
#        'Locality': x['property']['location']['locality'],
#        'Type of property': x['property']['type'],
#        'Subtype of property': x['property']['subtype'],
#        'Price': x['price']['mainValue'],
#        'Type of sale': x['price']['type'],
#        'Number of rooms': '?',  #Dont know what to take
#        'Area': x['property']['netHabitableSurface'],
#        'Fully equipped kitchen': x['property']['kitchen']['type'], #here are several values... look for fully equiped
#        'Furnished': '?',  #Dont know what to take
#        'Open fire': ['fireplaceExists'],
#        'Terrace': ['hasTerrace'],
#        'Terrace area': ['terraceSurface'],
#        'Garden': x['property']['hasGarden'],
#        'Garden area': x['property']['gardenSurface'],
#        'Surface of the land': x['property']['land']['surface'],
#        'Surface area of the plot of land': '?',  #Dont know what to take
#        'Number of facades ': x['property']['building']['facadeCount'],
#        'Swimming pool': x['property']['hasSwimmingPool'],
#        'State of the building': x['property']['building']['condition']    
#        }
#    return
#
#    
#    print('\n')

# %%
#import csv
#myFile = open('Demo.csv', 'r+')

#myDict = {'Roll': 4, 'Name': 'Joel', 'Language': 'Golang'}


#writer = csv.DictWriter(myFile, fieldnames=list(myDict.keys()))
#writer.writerow(myDict)

def main(list_list):
    #Create a base df with data from the url from the first page
    url_list1 = list_list[0]
    df = pd.DataFrame(url_to_list_dict(url_list1))
    #df = df.rename(index = lambda x: x + 1)
    print(df.head())
    df.to_csv("properties.csv")
    for i in  range(1,len(list_list)):
    #for i in range(len(houses_list)):
        #print(houses_list[i])
        df = df.merge(pd.DataFrame(url_to_list_dict(list_list[i])), how='outer')
        ##df = df.rename(index = lambda x: x + 1)
        print(df.head())
        #with open('properties.csv','a') as properties:
        #    properties.write(df2)
    
main(list_list)
# Out:
#                                                  url        id
# 0  https://www.immoweb.be/en/classified/house/for...  10125449
# 1      https://www.immoweb.be/en/classified/10125449  10125449
#                                                  url        id
# 0  https://www.immoweb.be/en/classified/house/for...  10125449
# 1      https://www.immoweb.be/en/classified/10125449  10125449
# 2  https://www.immoweb.be/en/classified/apartment...  10052020
# 3  https://www.immoweb.be/en/classified/apartment...  10052020
#                                                  url        id
# 0  https://www.immoweb.be/en/classified/house/for...  10125449
# 1      https://www.immoweb.be/en/classified/10125449  10125449
# 2  https://www.immoweb.be/en/classified/apartment...  10052020
# 3  https://www.immoweb.be/en/classified/apartment...  10052020
# 4  https://www.immoweb.be/en/classified/new-real-...  10140833
#                                                  url        id
# 0  https://www.immoweb.be/en/classified/house/for...  10125449
# 1      https://www.immoweb.be/en/classified/10125449  10125449
# 2  https://www.immoweb.be/en/classified/apartment...  10052020
# 3  https://www.immoweb.be/en/classified/apartment...  10052020
# 4  https://www.immoweb.be/en/classified/new-real-...  10140833
#                                                  url        id
# 0  https://www.immoweb.be/en/classified/house/for...  10125449
# 1      https://www.immoweb.be/en/classified/10125449  10125449
# 2  https://www.immoweb.be/en/classified/apartment...  10052020
# 3  https://www.immoweb.be/en/classified/apartment...  10052020
# 4  https://www.immoweb.be/en/classified/new-real-...  10140833
#                                                  url        id
# 0  https://www.immoweb.be/en/classified/house/for...  10125449
# 1      https://www.immoweb.be/en/classified/10125449  10125449
# 2  https://www.immoweb.be/en/classified/apartment...  10052020
# 3  https://www.immoweb.be/en/classified/apartment...  10052020
# 4  https://www.immoweb.be/en/classified/new-real-...  10140833
#                                                  url        id
# 0  https://www.immoweb.be/en/classified/house/for...  10125449
# 1      https://www.immoweb.be/en/classified/10125449  10125449
# 2  https://www.immoweb.be/en/classified/apartment...  10052020
# 3  https://www.immoweb.be/en/classified/apartment...  10052020
# 4  https://www.immoweb.be/en/classified/new-real-...  10140833
#                                                  url        id
# 0  https://www.immoweb.be/en/classified/house/for...  10125449
# 1      https://www.immoweb.be/en/classified/10125449  10125449
# 2  https://www.immoweb.be/en/classified/apartment...  10052020
# 3  https://www.immoweb.be/en/classified/apartment...  10052020
# 4  https://www.immoweb.be/en/classified/new-real-...  10140833
#                                                  url        id
# 0  https://www.immoweb.be/en/classified/house/for...  10125449
# 1      https://www.immoweb.be/en/classified/10125449  10125449
# 2  https://www.immoweb.be/en/classified/apartment...  10052020
# 3  https://www.immoweb.be/en/classified/apartment...  10052020
# 4  https://www.immoweb.be/en/classified/new-real-...  10140833
