# %% [markdown]
# ""
# import requests
# from bs4 import BeautifulSoup
#
# def get_pages_link(url):
#     baseurl = il link base..
#     r = requests.get(url)
#     #lxml??
#     sp = BeautifulSoup(r.text, 'lxml')
#     links = sp.select('li.product-grid...')
#     return [baseurl + link.attrs['herf'] for link in links]
#
#
#
# def product_data(url):
#     r = requests.get(url)
#     sp = BeautifulSoup(r.text, 'lxml')
#     product = {
#         #select_one()????????
#         'title' : sp.select_one('h1...name').text.strip().replae('\n','')
#         'price' : int(sp.select_one('h1...price').text.strip().replae('\$',''))
#         #...
#     }
#
# def main():
#     results = []
#     for x in range(1,3)
#         #facile se va così... e usa f
#         urls = get_pages_link(f'url{x}')
#         product_info = [product_data(url) for url in urls]
#         results.append(product_info)
#         print(f'page{x}')
#
#     return results
#
# print (main())
#
# import pandas as pd
# from itertools import chain
#
#
# df = pd.DataFrame(list(chain.from_iterable(main())))
# df.to_csv('file.csv', index = False)
# ""

# %%
from bs4 import BeautifulSoup

house_html = open("Apartment for sale in Deinze - Immoweb.html", "r")
  
# Reading the file
house_index = house_html.read()
  
# Creating a BeautifulSoup object and specifying the parser


def product_data(house_index):
    #r = requests.get(url)
    sp = BeautifulSoup(house_index, 'lxml')
    product = {
        #'Locality' : [ sp.select(x.strip().replace('\n','')) for x in sp.select('span.classified__information--address-row')],
        #.strip().replace('\n','')
        'Locality1' : sp.find_all(attrs={ "span" : "classified__information--address-row"}),
        #.strip().replace('\n',''),
        'Locality2' : sp.select_one('span.classified__information--address-row').text.strip().replace('\n','')

    }
        
        #'title' : sp.select_one('h1...name').text.strip().replace('\n','')
        #'price' : int(sp.select_one('h1...price').text.strip().replace('\$',''))
        
        #- Index < panda int >
        #'Url' : url
        

        #- Type of property (House/apartment) < str >
        #- Subtype of property (Bungalow, Chalet, Mansion, ...) < str >
        #- Price < float >
        #- Type of sale (Exclusion of life sales) < str >
        #- Number of rooms < float >
        #- Area < float >
        #- Fully equipped kitchen (Yes/No) <0 / 1>
        #- Furnished (Yes/No) <0 / 1>
        #- Open fire (Yes/No) <0 / 1>
        #- Terrace (Yes/No) <0 / 1>
        #    - If yes: Area <1>
        #- Garden (Yes/No) <0 / 1>
        #    - If yes: Area <1>
        #- Surface of the land < float >
        #- Surface area of the plot of land < float >
        #- Number of facades < float >
        #- Swimming pool (Yes/No) <0 / 1>
        #- State of the building (New, to be renovated, ...) < str >
    
 
    return product

print(product_data(house_index))
# Out:
# {'Locality1': [], 'Locality2': 'Tolpoortstraat 40'}

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# for holding the resultant list
element_list = []

house_html = open("Apartment for sale in Deinze - Immoweb.html", "r")
  
# Reading the file
house_index = house_html.read()
  



def product_data(url):
    #r = requests.get(url)
    driver = webdriver.Chrome('/home/piero/.local/bin/chromedriver')
    driver.get(url)
    
    cookie_button = driver.find_element(By.XPATH, '/html/body/div[3]/div[4]/div[2]/div/div[2]/div[1]/button').click()
    
    product = {
        #'Locality' : [ sp.select(x.strip().replace('\n','')) for x in sp.select('span.classified__information--address-row')],
        #.strip().replace('\n','')
        #'Locality1': driver.find_element(By.XPATH, '//button/span[2]/font[2]/font')
        #'Locality1' : sp.find_all(attrs={ "span" : "classified__information--address-row"}),
        
        #'Locality2' : sp.select_one('span.classified__information--address-row').text.strip().replace('\n','')
        #'title' : sp.select_one('h1...name').text.strip().replace('\n','')
        'price' : driver.find_element(By.XPATH, '//*[@id="classified-header"]/div/div/div[1]/div/div[2]/p/span[1]/font/font')
    }
        

        #- Index < panda int >
        #'Url' : url
        

        #- Type of property (House/apartment) < str >
        #- Subtype of property (Bungalow, Chalet, Mansion, ...) < str >
        #- Price < float >
        #- Type of sale (Exclusion of life sales) < str >
        #- Number of rooms < float >
        #- Area < float >
        #- Fully equipped kitchen (Yes/No) <0 / 1>
        #- Furnished (Yes/No) <0 / 1>
        #- Open fire (Yes/No) <0 / 1>
        #- Terrace (Yes/No) <0 / 1>
        #    - If yes: Area <1>
        #- Garden (Yes/No) <0 / 1>
        #    - If yes: Area <1>
        #- Surface of the land < float >
        #- Surface area of the plot of land < float >
        #- Number of facades < float >
        #- Swimming pool (Yes/No) <0 / 1>
        #- State of the building (New, to be renovated, ...) < str >
    
    driver.close()
    return product

url='https://www.immoweb.be/en/classified/apartment/for-sale/deinze/9800/10130388?searchId=633410276ba50'
print(product_data(url))
#closing the driver
# Out:
# /tmp/ipykernel_222729/2197388243.py:34: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/home/piero/.local/bin/chromedriver')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In [52], line 78
#      75     return product
#      77 url='https://www.immoweb.be/en/classified/apartment/for-sale/deinze/9800/10130388?searchId=633410276ba50'
# ---> 78 print(product_data(url))
#
# Cell In [52], line 36, in product_data(url)
#      34 driver = webdriver.Chrome('/home/piero/.local/bin/chromedriver')
#      35 driver.get(url)
# ---> 36 cookie_button = driver.find_element(By.XPATH, '/html/body/div[3]/div[4]/div[2]/div/div[2]/div[1]/button')
#      37 cookie_button.click()
#      39 product = {
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
  
# for holding the resultant list
element_list = []
  

page_url = "https://webscraper.io/test-sites/e-commerce/static/computers/laptops?page=1"
driver = webdriver.Chrome('/home/piero/.local/bin/chromedriver')
driver.get(page_url)
    
title = driver.find_element(By.CLASS_NAME, "title")
price = driver.find_element(By.CLASS_NAME, "price")
description = driver.find_element(By.CLASS_NAME, "description")
rating = driver.find_element(By.CLASS_NAME, "ratings")
  
print("a")
print(title,price,description,rating)
print("a")
#closing the driver
driver.close()
# Out:
# /tmp/ipykernel_222729/3428010799.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/home/piero/.local/bin/chromedriver')
# a
# <selenium.webdriver.remote.webelement.WebElement (session="d86f9759dc53a688f9c35b43b568b7bb", element="07dc7d12-087a-4117-830b-5de99377fb34")> <selenium.webdriver.remote.webelement.WebElement (session="d86f9759dc53a688f9c35b43b568b7bb", element="24c08638-0969-4e14-bc16-38fee52553eb")> <selenium.webdriver.remote.webelement.WebElement (session="d86f9759dc53a688f9c35b43b568b7bb", element="3a91ad81-53be-4ac0-87a2-278c427680cf")> <selenium.webdriver.remote.webelement.WebElement (session="d86f9759dc53a688f9c35b43b568b7bb", element="8417d685-4848-4162-aeae-fc383e3db636")>
# a

# %%
import time

from selenium import webdriver



driver = webdriver.Chrome('/home/piero/.local/bin/chromedriver.exe')  # Optional argument, if not specified will search path.

driver.get('http://www.google.com/');

time.sleep(5) # Let the user actually see something!

search_box = driver.find_element_by_name('q')

search_box.send_keys('ChromeDriver')

search_box.submit()

time.sleep(5) # Let the user actually see something!

driver.quit()
# Out:
# /tmp/ipykernel_222729/3711985479.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/home/piero/.local/bin/chromedriver.exe')  # Optional argument, if not specified will search path.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [54], line 13
#       9 driver.get('http://www.google.com/');
#      11 time.sleep(5) # Let the user actually see something!
# ---> 13 search_box = driver.find_element_by_name('q')
#      15 search_box.send_keys('ChromeDriver')
#      17 search_box.submit()
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_name'

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.implicitly_wait(10)


url = 'https://www.immoweb.be/en'

driver.get(url)


#cookie_button = driver.find_element(By.XPATH, '/html/body/div[3]/div[4]/div[2]/div/div[2]/div[1]/button')
#cookie_button.click()
cookie_button = driver.find_element(By.XPATH,'//[@id="uc-btn-accept-banner"]').click()
#cookie_button = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH,'//[@id="uc-btn-accept-banner"]'))).click()
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In [56], line 16
#      11 driver.get(url)
#      14 #cookie_button = driver.find_element(By.XPATH, '/html/body/div[3]/div[4]/div[2]/div/div[2]/div[1]/button')
#      15 #cookie_button.click()
# ---> 16 cookie_button = driver.find_element(By.XPATH,'//[@id="uc-btn-accept-banner"]').click()
#
# File ~/Desktop/Becode/Power_BI_env/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
#     857     'value': value})['value']
#
# File ~/Desktop/Becode/Power_BI_env/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:428, in WebDriver.execute(self, driver_command, params)
# ...

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import json
import pandas  as pd


#driver.implicitly_wait(10)

url = 'https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/testelt/3272/9920767'  #Use this link

def get_property(url):
    driver = webdriver.Chrome()
    driver.get(url)

    #Pass the cookkie banner
    time.sleep(2) #its better in a loop
    banner_button = driver.find_element(By.XPATH,'//*[@id="uc-btn-accept-banner"]').click()

    #info = driver.find_element(By.CLASS_NAME,'classified')  #Gets all info in the page
    #info = driver.find_element(By.XPATH,'//head/script[contains(text(),"window.dataLayer")]')
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    element_info = soup.select('div.classified script')

    #print(type(element_info))
    text = element_info[0].text
    OK = json.loads("".join(("".join(text.split('=')[1:]).split(";")[:-1])))
    house_dictionary = dict()
    house_dictionary = {
        
    }
    driver.close()

    #print(text[33:-2])

    return house_dictionary

#start = time.time()

#
url_list = ['https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/testelt/3272/9920767','https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/averbode/3271/10120498','https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/berlaar/2590/10130433']
#for url in url_list:
#    house_dictionary[url]=get_property(url)
#
#print(house_dictionary.keys())
#
#end = time.time()
#
#print("the time is:", end-start)
#

#data_open_fire = 0
#data_terrace = 0
#data_garden = 0
#data_surface_of_the_land = 0
#data_surface_of_the_plot_of_land = 0
#data_number_of_facades = 0
#data_swimming_pool = 0
#data_state_of_the_building = 0

#print('\n--------------\ninfo',info.text)
# Out:
# <bound method NDFrame.head of          id                                            cluster  \
# 0   9920767  {'minPrice': 346000, 'maxPrice': 349000, 'minS...
# 1  10120498  {'minPrice': 364500, 'maxPrice': 369500, 'minS...
# 2  10130433  {'minPrice': 325000, 'maxPrice': 399000, 'minS...
#
#                                            customers  \
# 0  [{'id': 2935516, 'type': 'AGENCY', 'email': 'h...
# 1  [{'id': 2935516, 'type': 'AGENCY', 'email': 'h...
# 2  [{'id': 2935516, 'type': 'AGENCY', 'email': 'h...
#
#                                   premiumProjectPage  \
# 0  {'medias': None, 'options': None, 'promoter': ...
# 1  {'medias': None, 'options': None, 'promoter': ...
# 2  {'medias': None, 'options': None, 'promoter': ...
#
#                                                flags  \
# 0  {'isPublicSale': False, 'isNewClassified': Fal...
# 1  {'isPublicSale': False, 'isNewClassified': Tru...
# 2  {'isPublicSale': False, 'isNewClassified': Tru...
#
# ...

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import json
import pandas  as pd

def product_data(url):
    driver = webdriver.Chrome()
    driver.get(url)
    #Pass the cookie banner
    time.sleep(3) #its better in a loop
    cookie_button = driver.find_element(By.XPATH,'//*[@id="uc-btn-accept-banner"]').click()
    #gather all the page info
    info = driver.find_element(By.CLASS_NAME,'classified')  #Gets all info in the page
    #extract locality info
    locality_raw = (info.find_elements(By.XPATH, '//span[@class="classified__information--address-row"]'))[1].text
    #make a dictionary
    product = {
        #- Index < panda int >
        'Url' : url ,
        'Locality' :  locality_raw,
        'Type of property' : (info.find_element(By.XPATH, '//h1[@class="classified__title"]').text).split()[0] ,
        #- Subtype of property (Bungalow, Chalet, Mansion, ...) < str >
        'Price' : (info.find_element(By.XPATH, '//p[@class="classified__price"]')).find_element(By.XPATH, '//p[@class="classified__price"]').text ,
        #- Type of sale (Exclusion of life sales) < str >
        #- Number of rooms < float >
        'area' : info.find_element(By.CLASS_NAME,'classified__information--property').text  #Gets specific info in the page
        #- Fully equipped kitchen (Yes/No) <0 / 1>
        #- Furnished (Yes/No) <0 / 1>        

    }
    #closing the driver
    driver.close()
    return product

url_list = ['https://www.immoweb.be/en/classified/house/for-sale/ixelles/1050/10008022?searchId=6336981899ac0', 
'https://www.immoweb.be/en/classified/apartment/for-sale/ixelles/1050/10141214?searchId=6336981899ac0'
#, 'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-st-lambert/1200/10052020?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/gent/9000/10140797?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/roeselare/8800/10140738?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/house/for-sale/remicourt/4350/10140833?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/apartment/for-sale/woluwe-saint-lambert/1200/10140583?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/apartment/for-sale/deinze/9800/10130388?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/apartment/for-sale/kessel-lo/3010/10142174?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/opwijk/1745/10140459?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/house/for-sale/ronse/9600/10140837?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/brussels-city/1000/9881253?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/duplex/for-sale/wichelen/9260/10138456?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/zedelgem/8210/10074861?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/wondelgem/9032/10139511?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/apartment/for-sale/leuven/3010/10138534?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/schilde/2970/10139639?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/house/for-sale/ronse/9600/10138497?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/apartment/for-sale/wezembeek-oppem/1970/10140213?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-houses/for-sale/wetteren/9230/10138446?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/bruxelles/1000/10092917?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/uccle/1180/10138601?searchId=6336981c0', 
#'https://www.immoweb.b899ae/en/classified/apartment/for-sale/woluwe-saint-lambert/1200/10138633?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/mixed-use-building/for-sale/grimbergen/1850/10138527?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/penthouse/for-sale/schaerbeek/1030/10142207?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/apartment-block/for-sale/ixelles/1050/10138311?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/flat-studio/for-sale/huy/4500/10137075?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/brasschaat/2930/10137774?searchId=6336981899ac0', 
#'https://www.immoweb.be/en/classified/flat-studio/for-sale/schaerbeek/1030/10137594?searchId=6336981899ac0'
, 'https://www.immoweb.be/en/classified/new-real-estate-project-apartments/for-sale/anderlecht/1070/10137324?searchId=6336981899ac0']
#
#def main(url_list):
#    #urls = get_page_link(url)
#    houses_list = [product_data(url) for url in url_list]
#    df = pd.DataFrame(houses_list)
#    df = df.rename(index = lambda x: x + 1)
#
#    print(df.describe())
#    df.to_csv("properties.csv")
#    #df.append(df2, ignore_index = True)
#main(url_list)

def main(url_list):
    ##urls = get_page_link(url)
    houses_list = [product_data(url) for url in url_list]
    #df = pd.DataFrame(houses_list)
    #df = df.rename(index = lambda x: x + 1)
    #print(df.describe())
    #df.to_csv("properties.csv")

    df = pd.DataFrame(houses_list)


    #df = df.rename(index = lambda x: x + 1)
    for i in range(len(houses_list)):
        print(i)
        #df2 = pd.DataFrame(houses_list[i])
        print(houses_list[i])
        #df.append(df2, ignore_index = True)
        ##df = df.rename(index = lambda x: x + 1)
        #print(df.describe())
        #df.to_csv(f"properties{i}.csv")
main(url_list)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [10], line 100
#      95         print(houses_list[i])
#      96         #df.append(df2, ignore_index = True)
#      97         ##df = df.rename(index = lambda x: x + 1)
#      98         #print(df.describe())
#      99         #df.to_csv(f"properties{i}.csv")
# --> 100 main(url_list)
#
# Cell In [10], line 82, in main(url_list)
#      80 def main(url_list):
#      81     ##urls = get_page_link(url)
# ---> 82     houses_list = [product_data(url) for url in url_list]
#      83     #df = pd.DataFrame(houses_list)
#      84     #df = df.rename(index = lambda x: x + 1)
#      85     #print(df.describe())
#      86     #df.to_csv("properties.csv")
#      88     df = pd.DataFrame(houses_list)
#
# Cell In [10], line 82, in <listcomp>(.0)
#      80 def main(url_list):
#      81     ##urls = get_page_link(url)
# ...
